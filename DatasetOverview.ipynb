# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/shin-sforzando/ctr-forecaster/blob/master/DatasetOverview.ipynb)

# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(color_codes=True)

# %%
df = pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/dataset/ctr.csv", index_col=0, names=("id", "ctr"))
df.head()
df.describe()
# Out:
#                ctr
# count  2065.000000
# mean      0.429673
# std       0.949983
# min       0.000000
# 25%       0.099098
# 50%       0.170773
# 75%       0.329242
# max      10.097131

# %%
df.ctr.plot.hist(bins=200, figsize=(20,10))
df.ctr.plot.kde(secondary_y=True, figsize=(20,10))

# %%
import keras
import keras.backend as K

from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns

img_path = Path("/content/gdrive/My Drive/Colab Notebooks/dataset/images/")
count = 0
for i in img_path.glob("*.jpg"):
  print("IMAGE:", i)
  
  img = Image.open(i)
  x = keras.preprocessing.image.img_to_array(img)
  print(x.shape, x.dtype)
  
  img = keras.preprocessing.image.load_img(i)
  plt.imshow(img)
  
  if 5 < count:
    break
  else:
    count += 1
# Out:
# Using TensorFlow backend.
# IMAGE: /content/gdrive/My Drive/Colab Notebooks/dataset/images/000845_3.125000000.jpg
# (250, 300, 3) float32
# IMAGE: /content/gdrive/My Drive/Colab Notebooks/dataset/images/000632_0.747592643.jpg
# (250, 300, 3) float32
# IMAGE: /content/gdrive/My Drive/Colab Notebooks/dataset/images/000528_2.610114192.jpg
# (250, 300, 3) float32
# IMAGE: /content/gdrive/My Drive/Colab Notebooks/dataset/images/000715_0.279111310.jpg
# (250, 300, 3) float32
# IMAGE: /content/gdrive/My Drive/Colab Notebooks/dataset/images/001719_0.735178693.jpg
# (250, 300, 3) float32
# IMAGE: /content/gdrive/My Drive/Colab Notebooks/dataset/images/000940_0.667234650.jpg
# (250, 300, 3) float32
# IMAGE: /content/gdrive/My Drive/Colab Notebooks/dataset/images/000481_0.071918110.jpg
# (250, 300, 3) float32
